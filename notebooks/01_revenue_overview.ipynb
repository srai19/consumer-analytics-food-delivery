# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/ecommerce_customer_behavior_dataset_v2.csv")

# Revenue overview metrics
result = pd.DataFrame({
    "Metric": ["Total Orders", "Total Customers", "Total Revenue", "Average Order Value"],
    "Value": [
        df["Order_ID"].nunique(),
        df["Customer_ID"].nunique(),
        df["Total_Amount"].sum(),
        df["Total_Amount"].mean()
    ]
})

result
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2286027631.py in <cell line: 0>()
#       2
#       3 # Load dataset
# ----> 4 df = pd.read_csv("/content/ecommerce_customer_behavior.csv")
#       5
#       6 # Revenue overview metrics
#
# ...

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("/content/ecommerce_customer_behavior_dataset_v2.csv")

# Revenue overview metrics
result = pd.DataFrame({
    "Metric": ["Total Orders", "Total Customers", "Total Revenue", "Average Order Value"],
    "Value": [
        df["Order_ID"].nunique(),
        df["Customer_ID"].nunique(),
        df["Total_Amount"].sum(),
        df["Total_Amount"].mean()
    ]
})

result
# Out:
#                 Metric         Value
# 0         Total Orders  1.704900e+04
# 1      Total Customers  5.000000e+03
# 2        Total Revenue  2.177905e+07
# 3  Average Order Value  1.277439e+03

# %% [markdown]
# ### Business Insight
#
# - Establishes the overall revenue scale of the platform.
# - Average order value provides baseline pricing insight.
# - This output will be used to compare profitability across customer segments.
